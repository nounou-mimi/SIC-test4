# %% [markdown]
# <a href="https://colab.research.google.com/github/nounou-mimi/SIC-test4/blob/main/problem_0401.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quiz #0401

# %% [markdown]
# ### "Optimal number of clusters for K-means clustering"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
# %matplotlib inline

# %% [markdown]
# #### Answer the following question by providing Python code:

# %%
# We will use simulated data.
# 3 clusters in 8 dimensional space.
# Hard to visualize!
X, label = make_blobs(n_samples=150, n_features=8, centers=3, cluster_std = 2, random_state=123)
X.shape
# Out:
# (150, 8)

# %% [markdown]
# 1). Define a function that calculates the "total internal sum of squares".
# - X         :   Data.
# - centers   :   Array that contains the centroid coordinates. Calculated by kmeans.
# - clusters  :   Array of cluster labels. Calculated by kmeans. <br> <br>
# HINT: Implement the formula from the lecture note.

# %%
def total_internal_ss(X, centers, clusters):
  N_clusters = centers.shape[0]
  N_columns = centers.shape[1]
  N_rows = X.shape[0]
  total=0
  for i in range(N_rows):
    cluster=clusters[i]
    for k in range(N_columns):
      total+=(X[i,k]-centers[cluster,k])**2
  return total

# %% [markdown]
# 2). Visualize as a Scatter plot the "total internal sum of squares" vs N# of clusters.
# - Then, determine the optimal number of clusters.
# - Is this number the same as expected?

# %%
n_cluster = range(2,10)                  # Array that contains the number of clusters.
total_ss = []                             # Array that will contain the total internal sum of squares.
for k in n_cluster:
  km=KMeans(k)
  clusters=km.fit_predict(X)
  centers=km.cluster_centers_
  print(total_internal_ss(X,centers,clusters))
  total_ss.append(total_internal_ss(X,centers,clusters))
plt.scatter(n_cluster,total_ss)
# Out:
# 10921.712724042549
# 4665.3013223949
# 4413.374739879902
# 4211.631262094244
# 4008.991365413369
# 3886.011394342649
# 3757.2536786139153
# 3563.866882009466

# %% [markdown]
# The optimal number of clusters is 3, because moving from 2 to 3 clusters we see the maximum drop in total internal sum of squares

# %%
       # <Your code goes in here>
